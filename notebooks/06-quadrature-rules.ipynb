# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy
import sympy.abc

# %%
x = sympy.abc.x
p = (x**8 - 1)
p
# Out:
# x**8 - 1

# %%
p.factor()
# Out:
# (x - 1)*(x + 1)*(x**2 + 1)*(x**4 + 1)

# %%
(p ** 2).expand()
# Out:
# x**16 - 2*x**8 + 1

# %%
sympy.integrate(p, x)
# Out:
# x**9/9 - x

# %%
sympy.integrate(p, (x, 0 , 1))
# Out:
# -8/9

# %%
trapez_nodes = np.array([0, 1], dtype=np.float64)
trapez_weights = np.array([1/ 2., 1/2.], dtype=np.float64)

# %%
trapez_rule = (trapez_nodes, trapez_weights)

# %%
trapez_rule[1]
# Out:
# array([0.5, 0.5])

# %%
from collections import namedtuple

# %%
QRule = namedtuple("QRule", ["nodes", "weights", "interval"])

# %%
trapez_rule = QRule(trapez_nodes, trapez_weights, (0, 1))

# %%
trapez_rule
# Out:
# QRule(nodes=array([0., 1.]), weights=array([0.5, 0.5]), interval=(0, 1))

# %%
trapez_rule.weights
# Out:
# array([0.5, 0.5])

# %%
trapez_rule[1]
# Out:
# array([0.5, 0.5])

# %%
for i in trapez_rule:
  print(i)
# Out:
# [0. 1.]
# [0.5 0.5]
# (0, 1)

# %%
class whatever:
  def __init__(self):
    self.a = 19
  
  def __getattr__(self, atrb):
    print(atrb)
    return 42

# %%
my_object = whatever()

# %%
my_object.__dict__
# Out:
# {'a': 19}

# %%
my_object.a == my_object.__dict__["a"]
# Out:
# True

# %%
my_object.something
# Out:
# something
# 42

# %%
def integrate(f, q_rule):
  return np.sum(q_rule.weights * f(q_rule.nodes))

# %%
- np.cos(1) + np.cos(0) - integrate(np.sin, trapez_rule)
# Out:
# 0.03896220172791198

# %%
def generate_equispaced_nodes(n):
  return np.linspace(0, 1, n + 1, endpoint=False)[1:
                                                  
leggauss
# Out:
#   File "<ipython-input-55-62de5ddd1a12>", line 4
#     leggauss
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
def generate_interpolatory_quadrature_rule(nodes):
  n_of_nodes = nodes.shape[0]
  if n_of_nodes == 1:
    weights = np.array([1.], dtype=np.float64)
    return QRule(nodes=nodes, weights=weights, interval=(0, 1))
  
  weights = np.empty((n_of_nodes,), dtype=np.float64)

  x = sympy.abc.x
  for i in range(n_of_nodes):
    k = 1
    for j in range(n_of_nodes):
      if i == j:
        continue
      k *= (x - nodes[j]) / (nodes[i] - nodes[j])
    weights[i] = sympy.integrate(k, (x, 0, 1))
  
  return QRule(nodes=nodes, weights=weights, interval=(0, 1))

# %%
generate_interpolatory_quadrature_rule(trapez_nodes)
# Out:
# QRule(nodes=array([0., 1.]), weights=array([0.5, 0.5]), interval=(0, 1))

# %%
from functools import lru_cache

@lru_cache(100)
def generate_nc_quadrature_rule(n):
  nodes = generate_equispaced_nodes(n)
  return generate_interpolatory_quadrature_rule(nodes)

# %%
errors = []
for i in range(1, 14):
  q_rule = generate_nc_quadrature_rule(i)
  q_result = integrate(np.sin, q_rule)
  exact_result = np.cos(0) - np.cos(1)
  error = np.abs(exact_result - q_result) / np.abs(exact_result)
  errors.append(error)

plt.yscale("log")
plt.plot(range(1, 14), errors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-8f2d8c379931> in <module>
#       1 errors = []
#       2 for i in range(1, 14):
# ----> 3   q_rule = generate_nc_quadrature_rule(i)
#       4   q_result = integrate(np.sin, q_rule)
#       5   exact_result = np.cos(0) - np.cos(1)
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
def estimate_nc_error(f, n_of_points):
  f_numpy = sympy.lambdify(x, f)
  exact_result = sympy.integrate(f, (sympy.abc.x, 0, 1))
  errors = []
  for i in range(1, n_of_points + 1):
    q_rule = generate_nc_quadrature_rule(i)
    q_result = integrate(f_numpy, q_rule)
    error = np.abs(exact_result - q_result) / np.abs(exact_result)
    errors.append(error)
  return errors

# %%
x = sympy.abc.x
f = x**2 - x ** 3 + sympy.sin(x)
f
# Out:
# -x**3 + x**2 + sin(x)

# %%
f.integrate(x)
# Out:
# -x**4/4 + x**3/3 - cos(x)

# %%
nodes = np.array([0, 0.2, 0.7])
f(nodes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-74facfa37973> in <module>
#       1 nodes = np.array([0, 0.2, 0.7])
# ----> 2 f(nodes)
#
# TypeError: 'Add' object is not callable

# %%
f_numpy = sympy.lambdify(x, f)

# %%
f_numpy(nodes)
# Out:
# array([0.        , 0.23066933, 0.79121769])

# %%
errors = estimate_nc_error(sympy.sin(x), 14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-77ce1b69d135> in <module>
# ----> 1 errors = estimate_nc_error(sympy.sin(x), 14)
#
# <ipython-input-31-a4b63cd982ed> in estimate_nc_error(f, n_of_points)
#       4   errors = []
#       5   for i in range(1, n_of_points + 1):
# ----> 6     q_rule = generate_nc_quadrature_rule(i)
#       7     q_result = integrate(f_numpy, q_rule)
#       8     error = np.abs(exact_result - q_result) / np.abs(exact_result)
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
plt.yscale("log")
plt.plot(range(1, 15), errors)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ffc9bcdec3ff> in <module>
#       1 plt.yscale("log")
# ----> 2 plt.plot(range(1, 15), errors)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (14,) and (0,)

# %%
errors = estimate_nc_error(x ** (5 / 2), 14)
plt.yscale("log")
plt.plot(range(1, 15), errors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-9c328409288b> in <module>
# ----> 1 errors = estimate_nc_error(x ** (5 / 2), 14)
#       2 plt.yscale("log")
#       3 plt.plot(range(1, 15), errors)
#
# <ipython-input-31-a4b63cd982ed> in estimate_nc_error(f, n_of_points)
#       4   errors = []
#       5   for i in range(1, n_of_points + 1):
# ----> 6     q_rule = generate_nc_quadrature_rule(i)
#       7     q_result = integrate(f_numpy, q_rule)
#       8     error = np.abs(exact_result - q_result) / np.abs(exact_result)
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
def scale_quadrature_rule(q_rule, a, b):
  """
  Take a q_rule defined on [0, 1] and move it on [a, b]
  """
  i_length = b - a
  new_nodes = a + i_length * q_rule.nodes
  new_weights = q_rule.weights * i_length

  return QRule(new_nodes, new_weights, (a, b))

# %%
def estimate_nc_error(f, n_of_points, a=0, b=1):
  f_numpy = sympy.lambdify(x, f)
  exact_result = sympy.integrate(f, (sympy.abc.x, a, b))
  errors = []
  for i in range(1, n_of_points + 1):
    q_rule = generate_nc_quadrature_rule(i)
    if a != 0 or b != 1:
      q_rule = scale_quadrature_rule(q_rule, a, b)
    q_result = integrate(f_numpy, q_rule)
    error = np.abs(exact_result - q_result) / np.abs(exact_result)
    errors.append(error)
  return errors

# %%
errors = estimate_nc_error(sympy.cos(x), 14, -5, 5)
plt.yscale("log")
plt.plot(range(1, 15), errors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-de8cdf093ddf> in <module>
# ----> 1 errors = estimate_nc_error(sympy.cos(x), 14, -5, 5)
#       2 plt.yscale("log")
#       3 plt.plot(range(1, 15), errors)
#
# <ipython-input-41-b668dec2cee8> in estimate_nc_error(f, n_of_points, a, b)
#       4   errors = []
#       5   for i in range(1, n_of_points + 1):
# ----> 6     q_rule = generate_nc_quadrature_rule(i)
#       7     if a != 0 or b != 1:
#       8       q_rule = scale_quadrature_rule(q_rule, a, b)
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
errors = estimate_nc_error(1 / (1 + x**2), 14, -5, 5)
plt.yscale("log")
plt.plot(range(1, 15), errors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-94ef6c8b41c7> in <module>
# ----> 1 errors = estimate_nc_error(1 / (1 + x**2), 14, -5, 5)
#       2 plt.yscale("log")
#       3 plt.plot(range(1, 15), errors)
#
# <ipython-input-41-b668dec2cee8> in estimate_nc_error(f, n_of_points, a, b)
#       4   errors = []
#       5   for i in range(1, n_of_points + 1):
# ----> 6     q_rule = generate_nc_quadrature_rule(i)
#       7     if a != 0 or b != 1:
#       8       q_rule = scale_quadrature_rule(q_rule, a, b)
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
def generate_composite_formula(base_rule, n_of_cells):
  base_n_of_points = base_rule.nodes.shape[0]
  n_of_points = base_n_of_points * n_of_cells

  new_nodes = np.empty((n_of_points,), dtype=np.float64)
  new_weights = np.empty_like(new_nodes)

  for i in range(n_of_cells):
    a = 1 / float(n_of_cells) * i
    b = a + 1 / float(n_of_cells)
    cell_q_rule = scale_quadrature_rule(base_rule, a, b)
    new_nodes[i * base_n_of_points : (i + 1) * base_n_of_points] = cell_q_rule.nodes
    new_weights[i * base_n_of_points : (i + 1) * base_n_of_points] = cell_q_rule.weights

  return QRule(new_nodes, new_weights, (0, 1))

# %%
base_rule = generate_nc_quadrature_rule(1)
generate_composite_formula(base_rule, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-150bb8c1aa5b> in <module>
# ----> 1 base_rule = generate_nc_quadrature_rule(1)
#       2 generate_composite_formula(base_rule, 4)
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
def estimate_error_against_cells(f, base_formula, n_of_cells, a=0, b=1):
  f_numpy = sympy.lambdify(x, f)
  exact_result = sympy.integrate(f, (sympy.abc.x, a, b))
  errors = []
  for i in range(1, n_of_cells + 1):
    q_rule = generate_composite_formula(base_formula, i)
    if a != 0 or b != 1:
      q_rule = scale_quadrature_rule(q_rule, a, b)
    q_result = integrate(f_numpy, q_rule)
    error = np.abs(exact_result - q_result) / np.abs(exact_result)
    errors.append(error)
  return errors

# %%
errors = estimate_error_against_cells(
    sympy.sin(x),
    generate_nc_quadrature_rule(2),
    14)
plt.yscale("log")
plt.plot(range(1, 15), errors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-3493f58d5761> in <module>
#       1 errors = estimate_error_against_cells(
#       2     sympy.sin(x),
# ----> 3     generate_nc_quadrature_rule(2),
#       4     14)
#       5 plt.yscale("log")
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
errors = estimate_error_against_cells(
    1 / (1 + x**2),
    generate_nc_quadrature_rule(2),
    14, -5, 5)
plt.yscale("log")
plt.plot(range(1, 15), errors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-b1f18007b2ba> in <module>
#       1 errors = estimate_error_against_cells(
#       2     1 / (1 + x**2),
# ----> 3     generate_nc_quadrature_rule(2),
#       4     14, -5, 5)
#       5 plt.yscale("log")
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
K = 50
errors1 = estimate_error_against_cells(
    sympy.sin(x),
    generate_nc_quadrature_rule(1),
    K)
errors2 = estimate_error_against_cells(
    sympy.sin(x),
    generate_nc_quadrature_rule(2),
    K)
errors3 = estimate_error_against_cells(
    sympy.sin(x),
    generate_nc_quadrature_rule(3),
    K)
errors4 = estimate_error_against_cells(
    sympy.sin(x),
    generate_nc_quadrature_rule(4),
    K)
errors5 = estimate_error_against_cells(
    sympy.sin(x),
    generate_nc_quadrature_rule(5),
    K)
plt.yscale("log")
plt.plot(range(1, K + 1), errors1, color="black")
plt.plot(range(1, K + 1), errors2, color="blue")
plt.plot(range(1, K + 1), errors3, color="green")
plt.plot(range(1, K + 1), errors4, color="gold")
plt.plot(range(1, K + 1), errors5, color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-98fd98676162> in <module>
#       2 errors1 = estimate_error_against_cells(
#       3     sympy.sin(x),
# ----> 4     generate_nc_quadrature_rule(1),
#       5     K)
#       6 errors2 = estimate_error_against_cells(
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined

# %%
K = 100
f = 1 / (1 + x**2)
errors1 = estimate_error_against_cells(
    f,
    generate_nc_quadrature_rule(1),
    K)
errors2 = estimate_error_against_cells(
    f,
    generate_nc_quadrature_rule(2),
    K)
errors3 = estimate_error_against_cells(
    f,
    generate_nc_quadrature_rule(3),
    K)
errors4 = estimate_error_against_cells(
    f,
    generate_nc_quadrature_rule(4),
    K)
errors5 = estimate_error_against_cells(
    f,
    generate_nc_quadrature_rule(5),
    K)
plt.yscale("log")
plt.plot(range(1, K + 1), errors1, color="black")
plt.plot(range(1, K + 1), errors2, color="blue")
plt.plot(range(1, K + 1), errors3, color="green")
plt.plot(range(1, K + 1), errors4, color="gold")
plt.plot(range(1, K + 1), errors5, color="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-51871481ba18> in <module>
#       3 errors1 = estimate_error_against_cells(
#       4     f,
# ----> 5     generate_nc_quadrature_rule(1),
#       6     K)
#       7 errors2 = estimate_error_against_cells(
#
# <ipython-input-27-b0e7ec8db65a> in generate_nc_quadrature_rule(n)
#       3 @lru_cache(100)
#       4 def generate_nc_quadrature_rule(n):
# ----> 5   nodes = generate_equispaced_nodes(n)
#       6   return generate_interpolatory_quadrature_rule(nodes)
#
# NameError: name 'generate_equispaced_nodes' is not defined
